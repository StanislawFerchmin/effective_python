# %% [markdown]
# ## Lab 04

# %% [markdown]
# ## Zadanie 1 (Igor Sieradzki)

# %% [markdown]
# Funkcja <t>flow_rate</i> do modyfikacji

# %%
from functools import reduce
def flow_rate(weight, time , **kwargs):
    """ Funkcja wylicza ile wagi produktu przybyło/ubyło w jednostce czasu """
    flow = weight / time
    # if not kwargs:
    #     return flow
    # kw_iter = iter(kwargs.values())
    # for v in kw_iter:
    #     flow *= v
    flow *= reduce( lambda x , y : x*y , kwargs.values() , 1)
    # reduce(function, iterable, initial) funkcje lambda obklada na kwargs.values z poczatkowym warunkiem 1 x=1 y= value1 lambda= x*y x = x*y y =value2 
    #  lambda =  value1*value2 break i flow mnożymy kolejno przez labda , lambda...
    return flow   

weight = 0.5
time = 3

# %%
flow = flow_rate(weight, time)
print("{0:.3} kg per second".format(flow))
# Out:
# 0.167 kg per second

# %%
Zmodyfikuj funckje <i>flow_rate</i> tak, aby poniższe wywołania działały poprawnie.

# %%
flow = flow_rate(weight, time, period=60, units_per_kg=1000)
print("{} grams per minute".format(flow))
# Out:
# 10000.0 grams per minute

# %%
flow = flow_rate(weight, time, period=1, units_per_kg=1)
print("{0:.3} kg per second".format(flow))
# Out:
# 0.167 kg per second

# %%
flow = flow_rate(weight, time)
print("{0:.3} grams per minute".format(flow))
# Out:
# 0.167 grams per minute

# %% [markdown]
# Wyjaśnić czemu poniższe rzucanie błędu jest porządane

# %%
try:
    flow = flow_rate(weight, time, 3600, 2.2)
except TypeError:
    print(True)
    # jest pożądane z uwagi na to że **kwargs to są argumenty z kluczami
# Out:
# True

# %% [markdown]
# ## Zadanie 2 (Igor Sieradzki)

# %% [markdown]
# Dopisz definicje dekoratora _timeit_, który wypisze na wyjscie standardowe czas wywołania udekorowanej funckji np.
#
# ```
# @timeit
# def foo(x):
#     return x**2
#
# r = foo(2)
# ```
# wypize: <br>
#     `Function foo took: 0.00001 seconds` <br>
# oraz zwróci 4

# %%
from time import time

def timeit(func):
    """ Wypisuje czas wywołania udekorowanej funckji """
    def wrapper(*args,**kwargs):
        start = time()
        result = func(*args,**kwargs)
        stop = time()
        print( f'Function {func.__name__} took {stop-start:.6f} seconds ')
        return result
    return wrapper

@timeit
def squares_list(n):
    squares = []
    for i in range(n):
        squares.append(i ** 2)
    return squares

@timeit
def squares_comprehension(n):
    return [i ** 2 for i in range(n)]

@timeit
def squares_map(n):
    return map(lambda x: x**2, range(n))

n = 1000000
l = squares_list(n)
c = squares_comprehension(n)
m = squares_map(n)
# Out:
# Function squares_list took 0.096801 seconds
# Function squares_comprehension took 0.078557 seconds
# Function squares_map took 0.000003 seconds

# %% [markdown]
# ## Zadanie 3 (Igor Sieradzki)

# %% [markdown]
# Dopisz definicje dekoratora _derivate_ wg. instrukcji w _docstringu_

# %%
import sys
sys.float_info.epsilon # epsilon maszynowy
def derivate(epsilon = 1000*sys.float_info.epsilon):
    h = epsilon
    def decorator(func):
        def wrapper(x):
            
            der = (func(x + h) - func(x))/h
            
            return der
        
        return wrapper            
   
    return decorator

@derivate(0.01)
def f(x):
    return x*x

@derivate(0.00001)
def g(x):
    return x*x*x+3

def test(a, b, eps=1):
    return abs(round(a)-round(b)) < eps

print(test(f(100), 200.0))
print(round(f(0)) == 0.0)

print(test(g(100), 30000.0))
print(round(g(0)) == 0.0)

from random import random
for x in [random()*1000. for _ in range(20)]:
    print(f(x), 2*x, '\t', test(f(x), 2*x))
    print(g(x), 3*x**2, '\t', test(g(x), 3*x**2))
# Out:
# True
# True
# True
# True
# 1884.9630953161977 1884.953095318443 	 True
# 2664786.148071289 2664786.1286629345 	 True
# 1926.0891258949414 1926.0791258929346 	 True
# 2782335.615158081 2782335.5994003685 	 True
# 31.14815816240082 31.138158162402398 	 True
# 727.1891373420657 727.1886703100903 	 True
# 1825.557450542692 1825.5474505376199 	 True
# 2499467.647075653 2499467.6206233026 	 True
# 875.2014856581809 875.1914856572705 	 True
# 574470.1147079468 574470.1024252352 	 True
# 312.3196642980474 312.309664298261 	 True
# 73152.99957990646 73152.99481056936 	 True
# 497.2066409245599 497.1966409252235 	 True
# 185403.38240563867 185403.37481049422 	 True
# 289.43796447820205 289.427964478546 	 True
# 62826.414359733455 62826.40996664587 	 True
# 609.4421263042022 609.4321263034943 	 True
# 278555.64653873444 278555.6374280987 	 True
# 1036.1629450693727 1036.1529450719936 	 True
# 805209.708213806 805209.6941860244 	 True
# 118.15953225132034 118.1495322513606 	 True
# 10469.485752400942 10469.483978411474 	 True
# 1641.948626935482 1641.9386269386532 	 True
# 2021971.8694686887 2021971.8409748925 	 True
# 1762.6821557292715 1762.6721557279725 	 True
# 2330259.85956192 2330259.846434023 	 True
# 1783.675345161464 1783.6653451595494 	 True
# 2386096.5609550476 2386096.5476423507 	 True
# 272.4740010991809 272.4640010994559 	 True
# 55677.478015422814 55677.47392134323 	 True
# 1852.40625863662 1852.3962586354241 	 True
# 2573528.9573669434 2573528.9242548877 	 True
# 1980.023786437232 1980.013786429671 	 True
# 2940340.971946716 2940340.945838672 	 True
# 151.59151400366682 151.58151400353083 	 True
# 17232.71882510744 17232.716540701957 	 True
# 419.26375446346356 419.25375446403757 	 True
# 131830.28921484947 131830.28297414363 	 True
# 1494.191559322644 1494.181559323603 	 True
# 1674433.9287281034 1674433.8991670352 	 True

# %% [markdown]
# ## Zadanie 4 (Igor Sieradzki)

# %% [markdown]
# Dopisz definicje dekoratora _accepts_ wg. instrukcji w _docstringu_

# %%
def accepts(*types):
    """Sprawdza czy udekorowanej funckji zostały podane odpowiednie parametry zdefiniowane 
       w argumentach dekoratora"""
    def decorator(func):
        def wrapper(*args, **kwargs):
            for arg  in args:
                if not isinstance(arg , types):
                    raise TypeError(f"Invalid type: {arg}")
            for key , value in kwargs.items():
                if not isinstance(value,types):
                    raise TypeError(f"Invalid type: {value}")
            return func(*args,**kwargs) 
        return wrapper
    return decorator

@accepts(str)
def capitalize(word):
    return word[0].upper() + word[1:]

print(capitalize('ola') == 'Ola')

try:
    capitalize(2)
except TypeError:
    print(True)

@accepts(float, int)
def static_pow(base, exp):
    return base ** exp 

print(static_pow(2., 2) == 4.)
print(static_pow(2., exp=2) == 4.)
print(static_pow(base=2., exp=2) == 4.)

try:
    static_pow('x', 10)
except TypeError:
    print(True)
    
try:
    static_pow(2, 2.2)
except TypeError:
    print(True)
# Out:
# True
# True
# True
# True
# True
# True

# %% [markdown]
# ## Zadanie 5 (Igor Sieradzki)

# %% [markdown]
# Dopisz definicje dekoratora _returns_ wg. instrukcji w _docstringu_

# %%
def returns(*types):
    """Sprawdza czy udekorowana funkcja zwraca poprawne argumenty, zdefiniowane w parametrach dekoratora"""
    def decorator(func):
        def wrapper(*args,**kwargs):
            test = func(*args,**kwargs)
            for val, typ in zip(test,types):
                if not isinstance(val,typ):
                    raise TypeError
            return test
        return wrapper
    return decorator     


@returns(str)
def str_only_identity(word):
    return word

print(str_only_identity('hello') == 'hello')

try:
    str_only_identity(10)
except TypeError:
    print(True)
    
@returns(int, int)
def split_indices(x):
    return x[0], x[1]

print(split_indices(x=[6,9]) == (6,9))

try:
    split_indices('AB')
except TypeError:
    print(True)
# Out:
# True
# True
# True
# True

# %% [markdown]
# ## Zadanie 6 (Igor Sieradzki)
# Stwórz dekorator cached służący do cachowania wywołań dowolnej funkcji, tzn. chcemy by:
# * wywołanie funkcji z określonymi argumentami miało miejsce tylko raz
# * funkcja mogła przyjmować dowolną liczbę nazwanych i nienazwanych argumentów
# * nie musi reagować poprawnie na domyślne argumenty, tzn. wywołanie funkcji z domyślnymi argumentami a podanie dokładnie takich samych może być traktowane jako dwa różne wywołania
# * na opakowanej funkcji można wywołać `.cache_reset()`, który usunie cache z pamięci
# * wywołanie `.cache_status()` zwraca string z opisem w postaci: <br>
#     `Function FUNCTION_NAME called X times, evaluated Y times`

# %%
from random import random
def cached(*args,**kwargs):
    def decorator(func):
        if not kwargs:
            return func(args)
    return decorator    
@cached
def foo(x, y=1, z=4):
    return random()
        
print(foo(3) == foo(3))
print(foo(4) == foo(4))
print(foo(3, z=-1, y=3) == foo(3, y=3, z=-1))
print(foo(3) != foo(x=3))
a = foo(3)
foo.cache_reset()
print(a != foo(3))
print(foo.cache_status() == 'Function foo called 10 times, evaluated 5 times')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 11
#       7 @cached
#       8 def foo(x, y=1, z=4):
#       9     return random()
# ---> 11 print(foo(3) == foo(3))
#      12 print(foo(4) == foo(4))
#      13 print(foo(3, z=-1, y=3) == foo(3, y=3, z=-1))
#
# Cell In[18], line 5, in cached.<locals>.decorator(func)
#       3 def decorator(func):
#       4     if not kwargs:
# ----> 5         return func(args)
#
# TypeError: 'int' object is not callable

# %% [markdown]
# ## Zadanie 7 (Krzysztof Hajto)

# %% [markdown]
# Napisz dekorator który będzie robić n-krotne złożenie funkcji, gdzie n jest parametrem dekoratora

# %%
from functools import reduce
def zlozenie(n):
    def decorator(func):
        def wrapper(x):
            return reduce(lambda acc, _ : func(acc), range(n), x)
        return wrapper
    return decorator    


@zlozenie(3)
def f1(x):
    return x+1

@zlozenie(2)
def f2(x):
    return x*x

@zlozenie(5)
def f3(word):
    return "".join(chr(ord(l)+1) for l in word)

print(f1(2)==5)
print(f2(3) == 81)
print(f3("alamakota")=="fqfrfptyf")
# Out:
# True
# True
# True

# %% [markdown]
# ## Zadanie 8 (Krzysztof Hajto)

# %% [markdown]
# Python nie ma wbudowanej instrukcji switch. Ale posiada anonimowe funkcje oraz słowniki. Zaimplementuj poniższy switch w postaci słownika funkcji.
# `
# int my_function(x, y) {
#
#
#     switch(x) {
#         case 1: return y*y;
#         case 2: return x+y;
#         case 3: return x*y;
#         case 4: return 0;
#     }
# }
# `
#
# PS. Nigdy nie róbcie tego w faktycznym kodzie :)

# %%
def my_function(x, y):
    switch = {
        1: lambda x , y : y*y,
        2: lambda x , y : x+y,
        3: lambda x , y : x*y,
        4: lambda x , y : 0
        }
    return switch[x](x,y)
# dziala po kluczu x
print(my_function(2,4)==6)
print(my_function(3,1)==3)
print(my_function(1,3)==9)
print(my_function(2,4)==6)
print(my_function(3,1)==3)
print(my_function(4,9)==0)
print(my_function(1,3)==9)
print(my_function(2,4)==6)
print(my_function(3,1)==3)
print(my_function(4,9)==0)
print(my_function(2,4)==6)
print(my_function(3,1)==3)
print(my_function(4,9)==0)
print(my_function(1,3)==9)
print(my_function(2,4)==6)
print(my_function(3,1)==3)
print(my_function(1,3)==9)
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
